# %%
import qaoa_rigetti as qr

# %%
edges= [(0,1), (1,2), (2,3), (3,0)]
angles, signals = qr.qaoa_maxcut_randsample(edges, [0.1,0.2,0.3,0.4], 10, 3, sample_size=1000, sample_size_reduced=30)

# %%
sparse_signal = qr.reconstruct_from_signal(angles, signals)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(sparse_signal)

# %%
edges= [(0,1), (1,2), (2,3)]
angles, signals = qr.qaoa_maxcut_randsample(edges, [0.1,0.2,0.3,0.4], 1000, 3, sample_size=1000, sample_size_reduced=30)
sparse_signal = qr.reconstruct_from_signal(angles, signals)
plt.plot(sparse_signal)

# %%
edges= [(0,1), (1,2), (2,3)]
angles, signals = qr.qaoa_maxcut_randsample(edges, [0.1,0.2,0.3,0.4], 100, 3, sample_size=1000, sample_size_reduced=30)
sparse_signal = qr.reconstruct_from_signal(angles, signals)
plt.plot(sparse_signal)

# %%
edges= [(0,1), (1,2), (2,3)]
angles, signals = qr.qaoa_maxcut_randsample(edges, [0.1,0.2,0.3,0.4], 10, 3, sample_size=1000, sample_size_reduced=30)
sparse_signal = qr.reconstruct_from_signal(angles, signals)
plt.plot(sparse_signal)

# %%
edges= [(0,1), (1,2), (2,3)]
angles, signals = qr.qaoa_maxcut_randsample(edges, [0.1,0.2,0.3,0.4], 100, 3, sample_size=50, sample_size_reduced=20)
sparse_signal = qr.reconstruct_from_signal(angles, signals)
plt.plot(sparse_signal)

# %%
qr.qaoa_maxcut_opt(edges, [0.1,0.2,0.3,0.4], shots=100,sweeps=3)
# Out:
# 0th sweep, 0th angle update: 0.57
# 0th sweep, 1th angle update: 0.631
# 0th sweep, 2th angle update: 1.522
# 0th sweep, 3th angle update: 1.482
# 1th sweep, 0th angle update: 1.488
# 1th sweep, 1th angle update: 1.489
# 1th sweep, 2th angle update: 1.499
# 1th sweep, 3th angle update: 1.498
# 2th sweep, 0th angle update: 1.495
# 2th sweep, 1th angle update: 1.384
# 2th sweep, 2th angle update: 1.471
# 2th sweep, 3th angle update: 1.492

# %%
qr.qaoa_maxcut_opt(edges, [0.1,0.2,0.3,0.4], shots=1000,sweeps=3)
# Out:
# 0th sweep, 0th angle update: 0.623
# 0th sweep, 1th angle update: 0.626
# 0th sweep, 2th angle update: 1.448
# 0th sweep, 3th angle update: 1.517
# 1th sweep, 0th angle update: 1.445
# 1th sweep, 1th angle update: 1.558
# 1th sweep, 2th angle update: 1.532
# 1th sweep, 3th angle update: 1.996
# 2th sweep, 0th angle update: 1.999
# 2th sweep, 1th angle update: 2.0
# 2th sweep, 2th angle update: 1.991
# 2th sweep, 3th angle update: 1.99

# %%
qr.qaoa_maxcut_opt(edges, [0.1,0.2,0.3,0.4], shots=10,sweeps=3)
# Out:
# 0th sweep, 0th angle update: 0.587
# 0th sweep, 1th angle update: 0.621
# 0th sweep, 2th angle update: 1.457
# 0th sweep, 3th angle update: 1.329
# 1th sweep, 0th angle update: 1.3
# 1th sweep, 1th angle update: 1.268
# 1th sweep, 2th angle update: 1.44
# 1th sweep, 3th angle update: 1.489
# 2th sweep, 0th angle update: 1.484
# 2th sweep, 1th angle update: 1.549
# 2th sweep, 2th angle update: 1.589
# 2th sweep, 3th angle update: 1.534

# %%
qr.qaoa_maxcut_opt(edges, [0,0,0,0], shots=10,sweeps=3)
# Out:
# 0th sweep, 0th angle update: 0.0
# 0th sweep, 1th angle update: 0.0
# 0th sweep, 2th angle update: 1.513
# 0th sweep, 3th angle update: 1.411
# 1th sweep, 0th angle update: 1.48
# 1th sweep, 1th angle update: 1.551
# 1th sweep, 2th angle update: 1.504
# 1th sweep, 3th angle update: 1.744
# 2th sweep, 0th angle update: 1.749
# 2th sweep, 1th angle update: 1.931
# 2th sweep, 2th angle update: 1.788
# 2th sweep, 3th angle update: 1.71

# %%
qr.qaoa_maxcut_opt(edges, [0,0,0,0], shots=100,sweeps=3)
# Out:
# 0th sweep, 0th angle update: 0.0
# 0th sweep, 1th angle update: 0.0
# 0th sweep, 2th angle update: 1.486
# 0th sweep, 3th angle update: 1.437
# 1th sweep, 0th angle update: 1.459
# 1th sweep, 1th angle update: 1.477
# 1th sweep, 2th angle update: 1.522
# 1th sweep, 3th angle update: 1.973
# 2th sweep, 0th angle update: 1.985
# 2th sweep, 1th angle update: 1.959
# 2th sweep, 2th angle update: 1.933
# 2th sweep, 3th angle update: 1.949

# %%
qr.qaoa_maxcut_opt(edges, [0,0,0,0], shots=1000,sweeps=3)
# Out:
# 0th sweep, 0th angle update: 0.0
# 0th sweep, 1th angle update: 0.0
# 0th sweep, 2th angle update: 1.51
# 0th sweep, 3th angle update: 1.541
# 1th sweep, 0th angle update: 1.502
# 1th sweep, 1th angle update: 1.505
# 1th sweep, 2th angle update: 1.529
# 1th sweep, 3th angle update: 1.719
# 2th sweep, 0th angle update: 1.684
# 2th sweep, 1th angle update: 1.974
# 2th sweep, 2th angle update: 1.978
# 2th sweep, 3th angle update: 2.01
